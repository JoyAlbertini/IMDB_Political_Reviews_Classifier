# %% [markdown]
# # Political Bias
#
# Joy Albertini

# %% [markdown]
# python -m spacy download en_core_web_lg
# https://huggingface.co/datasets/JyotiNayak/political_ideologies
# pip install spacy-lookups-data

# %%
MODEL_DIR = './NLP/spacy_model'
MODEL_BEST = './NLP/spacy_model/model-best/'
TEST = './NLP/political_test.spacy'
TRAIN = './NLP/political_train.spacy'
VALIDATION = './NLP/political_validation.spacy'
CONFIG = './NLP/config.cfg'

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from spacy.cli.train import train
import spacy
from spacy.tokens import DocBin
from sklearn.metrics import classification_report

# %% [markdown]
# Spacy version

# %%
print("spaCy version:", spacy.__version__)
# Out:
# spaCy version: 3.7.4

# %% [markdown]
# ### Train / Test / Validation

# %%
def replace_label(df):
    label_map = {1: 'left', 0: 'right'}
    df['label'] = df['label'].map(label_map)
    
def clean(df):
    label_map = {"Left": 'left', "Right": 'right', "Neutral": 'neutral'}
    df.drop(['ID'], axis=1, inplace=True)
    df['label'] = df['label'].map(label_map)
    
def shuffle_rows(df): 
     return df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Train 1

# %%
df_train = pd.read_parquet("Train_dataset/political_bias_train.parquet")
replace_label(df_train)
df_train.head()
# Out:
#                                            statement  label  issue_type  \
# 0  Climate change, and the escalating environment...   left           1
# 1  I believe in the foundational importance of th...  right           2
# 2  I firmly believe that the principle of separat...   left           6
# 3  I firmly believe in the separation of church a...   left           6
# 4  I firmly believe in the power of free markets ...  right           0
#
#    __index_level_0__
# 0                465
# 1               1191
# 2               2440
# 3               2406
# 4               1903

# %%
df_train_2 = pd.read_csv("Train_dataset/film_reviews_train.csv")
df_train_2_neutral = pd.read_csv("Train_dataset/film_neutral.csv")
clean(df_train_2)
clean(df_train_2_neutral)
df_train_2 = pd.concat([df_train_2_neutral, df_train_2], ignore_index=True)
shuffle_rows(df_train)
df_train_2.head()
# Out:
#                                            statement    label
# 0  Provides an insightful look into the character...  neutral
# 1  The editing is sharp and adds to the narrative...  neutral
# 2  The film's pacing is inconsistent, with some p...  neutral
# 3  Features ambitious themes that aren't fully re...  neutral
# 4  Features ambitious themes that aren't fully re...  neutral

# %%
df_test = pd.read_parquet("Train_dataset/political_bias_test.parquet")
replace_label(df_test)
df_test.head()
# Out:
#                                            statement  label  issue_type  \
# 0  While respecting individual rights is paramoun...  right           7
# 1  The continuous economic dependence on China ha...  right           3
# 2  I firmly believe in the sanctity and tradition...  right           2
# 3  While I recognize and empathize with the chall...  right           5
# 4  I firmly believe in preserving the integrity o...  right           6
#
#    __index_level_0__
# 0               1777
# 1               1342
# 2               2700
# 3               3100
# 4                984

# %%
df_test_2 = pd.read_csv("Train_dataset/film_reviews_test.csv")
clean(df_test_2)
df_train_2.head()
# Out:
#                                            statement    label
# 0  Provides an insightful look into the character...  neutral
# 1  The editing is sharp and adds to the narrative...  neutral
# 2  The film's pacing is inconsistent, with some p...  neutral
# 3  Features ambitious themes that aren't fully re...  neutral
# 4  Features ambitious themes that aren't fully re...  neutral

# %%
df_validation = pd.read_parquet("Train_dataset/political_bias_validation.parquet")
replace_label(df_validation)
df_validation.head()
# Out:
#                                            statement  label  issue_type  \
# 0  I firmly believe that all individuals, regardl...  right           5
# 1  I believe that we should work towards more dip...   left           3
# 2  I firmly believe in the importance of acknowle...   left           5
# 3  The traditional family structure, with a mothe...  right           2
# 4  I believe in the importance of providing equal...   left           2
#
#    __index_level_0__
# 0               1563
# 1               1286
# 2               1425
# 3               1108
# 4               1031

# %%
df_validation_2 = pd.read_csv("Train_dataset/film_reviews_validation.csv")
clean(df_validation_2)
df_validation_2.head()
# Out:
#                                            statement    label
# 0  Stresses the importance of military strength i...    right
# 1  Highlights the role of renewable energy in mit...     left
# 2  Commemorates the achievements of industrial pi...    right
# 3  Delivers an impartial analysis of various film...  neutral
# 4  Demands global action against the wealth inequ...     left

# %% [markdown]
# ### Convert train and test to docbin

# %%
df_train = pd.concat([df_train, df_train_2], ignore_index=True)
df_test = pd.concat([df_test, df_test_2], ignore_index=True)
df_validation = pd.concat([df_validation, df_validation_2], ignore_index=True)

# %%
df_train = df_train_2
df_test = df_test_2
df_validation = df_validation_2

# %%
df_train = shuffle_rows(df_train)
df_test = shuffle_rows(df_test)
df_validation = shuffle_rows(df_validation)

nlp = spacy.load(MODEL_BEST)
def df2docbin(df, nlp):
    docbin = DocBin()
    for _, row in df.iterrows():
        doc = nlp.make_doc(row['statement'])
        cats = {
            'right': 1 if row['label'].lower() == 'right' else 0.0,
            'left': 1 if row['label'].lower() == 'left' else 0.0,
            'neutral': 1.0 if row['label'].lower() == 'neutral' else 0.0
        }
        doc.cats = cats
        docbin.add(doc)
    return docbin


docbin_train = df2docbin(df_train, nlp)
docbin_test = df2docbin(df_test, nlp)
docbin_validation = df2docbin(df_validation, nlp)

docbin_train.to_disk(TRAIN)
docbin_test.to_disk(TEST)
docbin_validation.to_disk(VALIDATION)

# %% [markdown]
# ### Train the model

# %%
train(output_path=MODEL_DIR, use_gpu=-1, config_path=CONFIG)
# Out:
# ℹ Saving to output directory: NLP/spacy_model
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTCAT  CATS_SCORE  CATS_MICRO_P  CATS_MICRO_R  SCORE
# ---  ------  ------------  ----------  ------------  ------------  ------
#   0       0          0.22       33.97         45.07         45.07    0.41
#   0     200         10.18       48.68         54.73         54.73    0.52
#   0     400          0.00       54.56         65.59         65.59    0.61
#   1     600          0.03       54.56         65.59         65.59    0.61
#   1     800          0.00       71.59         75.25         75.25    0.73
#   2    1000          0.00       78.15         80.08         80.08    0.79
#   3    1200          0.00       78.15         80.08         80.08    0.79
#   4    1400          0.02       78.15         80.08         80.08    0.79
#   6    1600          0.00       54.56         65.59         65.59    0.61
#   8    1800          0.00       54.56         65.59         65.59    0.61
#  10    2000          0.00       54.56         65.59         65.59    0.61
#  13    2200          0.00       54.56         65.59         65.59    0.61
#  16    2400          0.00       54.56         65.59         65.59    0.61
#  20    2600          0.00       54.56         65.59         65.59    0.61
# ✔ Saved pipeline to output directory
# NLP/spacy_model/model-last

# %% [markdown]
# ### Evaluate the model

# %%
nlp = spacy.load(MODEL_BEST)
validation_data = DocBin().from_disk(VALIDATION)
validate_docs = list(validation_data.get_docs(nlp.vocab))


def evaluate(nlp, docs):
    true_labels = []
    predicted_labels = []
    
    for doc in docs:
        true_labels.append(max(doc.cats, key=doc.cats.get))  
        pred_doc = nlp(doc.text)  
        predicted_labels.append(max(pred_doc.cats, key=pred_doc.cats.get))  

    report = classification_report(true_labels, predicted_labels, output_dict=True)
    return pd.DataFrame(report).transpose()  

eval_results = evaluate(nlp, validate_docs)

print("Evaluation Results:")
print(eval_results.round(2))
# Out:
# Evaluation Results:
#               precision  recall  f1-score  support
# left               1.00    0.61      0.76    36.00
# neutral            1.00    0.67      0.80    33.00
# right              0.55    1.00      0.71    31.00
# accuracy           0.75    0.75      0.75     0.75
# macro avg          0.85    0.76      0.76   100.00
# weighted avg       0.86    0.75      0.76   100.00

# %% [markdown]
# ### Validation

# %%
def print_prediction_results(df, column_name, tc, nlp):
    for index, row in df.iterrows():
        doc = nlp.make_doc(row[column_name])
        
        result = tc.predict([doc])
        
        max_score = -1
        max_label = ""
        
        for label, score in zip(tc.labels, result[0]):
            if score > max_score:
                max_score = score
                max_label = label
        
        print(f"Document: {row[column_name]}")
        print(f"Predicted Sentiment: {max_label} ({max_score*100:.2f}%)")
        print(f"Correct Sentiment: {row['label']}")
        print("===========================")

loaded_model = spacy.load(MODEL_BEST)
textcat = loaded_model.get_pipe('textcat')
print_prediction_results(df_validation, 'statement', textcat, nlp)
# Out:
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: Delivers an impartial analysis of various film adaptations of classic literature.
# Predicted Sentiment: neutral (99.99%)
# Correct Sentiment: neutral
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Focuses on the art of film making, providing a detailed critique of directing and editing techniques.
# Predicted Sentiment: right (100.00%)
# Correct Sentiment: neutral
# ===========================
# Document: Highlights the role of renewable energy in mitigating climate crisis with persuasive urgency.
# Predicted Sentiment: left (76.36%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: Demands global action against the wealth inequality exacerbated by capitalist systems.
# Predicted Sentiment: left (80.60%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Explores the evolution of film music from silent cinema to contemporary soundtracks.
# Predicted Sentiment: neutral (98.85%)
# Correct Sentiment: neutral
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Stresses the importance of military strength in maintaining global peace and stability.
# Predicted Sentiment: right (50.06%)
# Correct Sentiment: right
# ===========================
# Document: Commemorates the achievements of industrial pioneers who fueled economic growth.
# Predicted Sentiment: right (99.03%)
# Correct Sentiment: right
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================
# Document: Champions the role of free markets in driving innovation and prosperity.
# Predicted Sentiment: right (99.45%)
# Correct Sentiment: right
# ===========================
# Document: A searing indictment of corporate monopolies and their devastating impact on small communities.
# Predicted Sentiment: right (79.75%)
# Correct Sentiment: left
# ===========================

# %% [markdown]
# ## Test reviews

# %%
df_purge = pd.read_csv("Data/tt6133466/tt6133466_review.csv")
df_purge.head()
# Out:
#                                         review_title  \
# 0                   A painful way to spend your time
# 1  Weakest of The Purge films, but it remains a f...
# 2                         Had Potential, Falls short
# 3               Worst Purge movie out of all of them
# 4                              Really amusing movie.
#
#                                          review_body  rating      review_date
# 0                                                NaN     4.0  6 February 2020
# 1  This fourth installment in the fascinating, bu...     6.0   1 October 2018
# 2                                                NaN     5.0      4 July 2018
# 3  The characters are underdeveloped and the acti...     3.0     24 July 2021
# 4  I haven't seen the original Purge movies. And ...     7.0    4 August 2018

# %% [markdown]
# Reviews with high and small rating are more probable to have political bias

# %%
def filter_outside_range(df, min_rating, max_rating):
    df_filtered = df[(df['rating'] <= min_rating) | (df['rating'] >= max_rating)]
    return df_filtered


df_purge_filtered = filter_outside_range(df_purge, 1, 10)
len(df_purge_filtered)
df_purge_filtered.head(20)
# Out:
#                                           review_title  \
# 18   The worst Marvel movie to date (which is sayin...
# 20                              Lower, Further, Slower
# 23                         Huge Contender for a Razzie
# 36                                 Disney Ain't Marvel
# 49                           As Un-Marvelous as can be
# 59   2002 was the last time I walked out of a movie...
# 72   A Marvelous Misfire: How 'The Marvels' Misses ...
# 74                               You ruined Cpt Marvel
# 80                    The MCU has hit rock bottom.....
# 86     Never write reviews but this tragedy needed one
# 92                                A disgrace to Marvel
# 94                  Left the cinema before it finished
# 97         Wow this is the Definition of a Bad Movie..
# 111      Someone was really paid for creating this????
# 113                             Space Balls the ripoff
# 116  A truly appalling mess - my guess it was desig...
# 119                               Mind-numbingly awful
# 121  Worst film I've ever seen, left cinema couldn'...
# 123                                           Disaster
# 126                                 Why was this made?
#
#                                            review_body  rating  \
# 18                                                 NaN     1.0
# 20   This film is somehow way more depressing and w...     1.0
# 23   This second installment makes the original Cap...     1.0
# 36   So Stan Lee passes away and we get Disney now ...     1.0
# 49                                                 NaN     1.0
# 59   That changed today. Forget about "worst Marvel...     1.0
# 72                                                 NaN     1.0
# 74                                                 NaN     1.0
# 80   I don't follow the Internet for all of the new...     1.0
# 86                                                 NaN     1.0
# 92   If you can't come up with story which is as go...     1.0
# 94   What on earth was that? I have NEVER left the ...     1.0
# 97   Wow i have never seen such a boring uninterest...     1.0
# 111  TL;DR Awful plot, soooo awful role playing. Mo...     1.0
# 113                                                NaN     1.0
# 116  A truly appalling mess -designed for 8 year ol...     1.0
# 119  I haven't seen anything this awful for a long ...     1.0
# 121  By far the worst movie I've ever seen and I'm ...     1.0
# 123  This is one of the worst Marvel movies ever. S...     1.0
# 126                                                NaN     1.0
#
#           review_date
# 18     9 January 2024
# 20   23 December 2023
# 23   10 November 2023
# 36    16 January 2024
# 49   13 November 2023
# 59    9 November 2023
# 72   15 November 2023
# 74   23 December 2023
# 80   17 November 2023
# 86   13 November 2023
# 92   11 November 2023
# 94   14 November 2023
# 97   14 November 2023
# 111  23 December 2023
# 113  19 November 2023
# 116  11 November 2023
# 119   22 January 2024
# 121  19 November 2023
# 123  20 November 2023
# 126  20 November 2023

# %%
import textwrap
import numpy as np

def predict_reviews(df, model, nlp):
    df_filtered = df.dropna(subset=['review_title', 'review_body'])
    docs_with_ratings = [
        (nlp(title + " " + body), rating, title) 
        for title, body, rating in zip(df_filtered['review_title'], df_filtered['review_body'], df_filtered['rating'])
    ]
    results = []
    for doc, rating, title in docs_with_ratings:
        prediction_scores = model.predict([doc])[0]
        max_index = np.argmax(prediction_scores)
        max_score = prediction_scores[max_index]
        max_label = model.labels[max_index]
        
        doc_result = {
            "review_title": title,
            "document": doc.text, 
            "politics": max_label,
            "confidence": max_score,
            "rating": rating,
            "text_length": len(doc.text)
        }
        results.append(doc_result)
    
    return pd.DataFrame(results)

def confidence_threshold(df, threshold):
    high_confidence_df = df[df['confidence'] > threshold]
    high_confidence_df['text_length'] = high_confidence_df['document'].apply(len)
    sort_by_confidence(df)
    
def sort_by_confidence(df):
    return df.sort_values(by='confidence', ascending=False)

def sort_by_text_len(df):
    return df.sort_values(by='text_length', ascending=False)

def split_by_politics(df, label):
    return df[df['politics'] == label]

from IPython.display import display, HTML

# Function to display DF with nicer HTML formatting
def display_df_with_style(df):
    styles = [
        dict(selector="th", props=[("text-align", "left")]),
        dict(selector="td", props=[
            ("text-align", "left"),
            ("white-space", "pre-wrap"),
            ("border", "1px solid black"),
            ("font-family", "consolas")
        ])
    ]
    return df.style.set_table_styles(styles)

# %%
nlp = spacy.load(MODEL_BEST)
textcat = loaded_model.get_pipe('textcat')
df_purge_predicted = predict_reviews(df_purge, textcat, nlp)
print(len(df_purge_predicted))
df_purge_predicted.head(50)
# Out:
# 471
#                                          review_title  \
# 0   Weakest of The Purge films, but it remains a f...
# 1                Worst Purge movie out of all of them
# 2                               Really amusing movie.
# 3                    Sigh...what a waste of potential
# 4                        A Solid if Imperfect Prequel
# 5                  Go in knowing what you're watching
# 6              Movie was the best of the purge series
# 7                                    Political divide
# 8                            Horrible, racist garbage
# 9                                     Unfairly bashed
# 10                            Time to purge the purge
# 11            Not as bad as described in the comments
# 12                                   Absolutely Awful
# 13                                  Absolute Garbage.
# 14                                          Cheap Fun
# 15                           This is NOT a purge film
# 16                                   Not A Good Movie
# 17                                    What we see....
# 18                                 Utterly ridiculous
# 19  Not as amazing as the previous Purges but grea...
# 20                      Worst movie in the set by far
# 21               So far the worst movie of the summer
# 22                      Nothing new about human race.
# 23          Very different Purge lots of ghetto stuff
# 24                     I enjoyed it on the big screen
# 25                                      Really scary!
# 26                    What movie were y'all watching?
# 27                                   A Decent Prequel
# 28                                 Embarrassingly BAD
# 29                        A Beyond Lacklustre Prequel
# 30                  Is this the end, or the beginning
# 31                                Absolutely terrible
# 32                                               Good
# 33                                           my notes
# 34                               Reasonable prequel !
# 35                               A good action movie.
# 36                       Back To Where It All Started
# 37                     Good series ruined by politics
# 38                               An absolute disgrace
# 39                    On par with the original Purge.
# 40                                    The worst purge
# 41         Another Solid Entry for the Purge Faithful
# 42                     Original Fan from day- NO MORE
# 43                            intriguing origin story
# 44  The First Purge: The First Purge is the worst ...
# 45                              More than I expected.
# 46                      The tired and pointless purge
# 47              The First Purge - Spoiler Free Review
# 48                                           Terrible
# 49                                   Just not good...
#
#                                              document politics  confidence  \
# 0   Weakest of The Purge films, but it remains a\n...  neutral    0.997921
# 1   Worst Purge movie out of all of them The\nchar...  neutral    0.997580
# 2   Really amusing movie. I haven't seen the origi...  neutral    0.999466
# 3   Sigh...what a waste of potential It's a dreadf...  neutral    0.999454
# 4   A Solid if Imperfect Prequel Many of these IMD...  neutral    0.997995
# 5   Go in knowing what you're watching It's not a\...  neutral    0.958414
# 6   Movie was the best of the purge series I do no...  neutral    0.999485
# 7   Political divide If you actually think this mo...  neutral    0.997804
# 8   Horrible, racist garbage In the movie all whit...  neutral    0.994160
# 9   Unfairly bashed If you like the previous movie...  neutral    0.977564
# 10  Time to purge the purge This film was embarras...  neutral    0.997209
# 11  Not as bad as described in the comments First,...    right    0.932201
# 12  Absolutely Awful Was this movie written for 7 ...  neutral    0.999754
# 13  Absolute Garbage. My expectations going into b...  neutral    0.999982
# 14  Cheap Fun For the record I'm not going to begi...  neutral    0.999984
# 15  This is NOT a purge film It really is a shame ...  neutral    0.999998
# 16  Not A Good Movie I cannot believe how bad this...  neutral    0.999996
# 17  What we see.... Those of us outside the US can...  neutral    0.999991
# 18  Utterly ridiculous I m writing this review whi...  neutral    0.999990
# 19  Not as amazing as the previous Purges but grea...  neutral    1.000000
# 20  Worst movie in the set by far Unbelievably bad...  neutral    0.999958
# 21  So far the worst movie of the summer This movi...  neutral    0.998888
# 22  Nothing new about human race. Another film abo...  neutral    0.998645
# 23  Very different Purge lots of ghetto stuff More...  neutral    0.999583
# 24  I enjoyed it on the big screen Fourth film in ...  neutral    0.999984
# 25  Really scary! I finished the movie on HBO OnDe...  neutral    0.773888
# 26  What movie were y'all watching? Did me and\nev...  neutral    0.999996
# 27  A Decent Prequel For me The Purge series has\n...  neutral    0.999884
# 28  Embarrassingly BAD I was embarrassed sitting i...  neutral    0.999996
# 29  A Beyond Lacklustre Prequel I'm not a big horr...  neutral    0.999806
# 30  Is this the end, or the beginning Ok so there ...  neutral    0.999941
# 31  Absolutely terrible I couldn't even finish\nwa...  neutral    0.999984
# 32  Good Far from great but the acting was some\ns...  neutral    0.998982
# 33  my notes Pointless. useless. dumb. terrible.\n...    right    0.739665
# 34  Reasonable prequel ! First Purge is the best i...  neutral    0.999816
# 35  A good action movie. For goodness sake, stop o...  neutral    0.781409
# 36  Back To Where It All Started It was an idea th...    right    0.967761
# 37  Good series ruined by politics What I loved ab...  neutral    0.999995
# 38  An absolute disgrace I nearly missed half this...    right    0.654968
# 39  On par with the original Purge. The tension of...  neutral    0.999768
# 40  The worst purge Seriously, you get bored from ...  neutral    0.999998
# 41  Another Solid Entry for the Purge Faithful Ins...  neutral    0.996598
# 42  Original Fan from day- NO MORE This is the\nab...  neutral    0.999984
# 43  intriguing origin story The American economy h...  neutral    0.996701
# 44  The First Purge: The First Purge is the worst\...    right    0.994343
# 45  More than I expected. This movie was really\ne...  neutral    0.953526
# 46  The tired and pointless purge Disked 'The Purg...  neutral    0.999983
# 47  The First Purge - Spoiler Free Review I guess\...  neutral    0.999975
# 48  Terrible Never wrote a review on a movie, but ...  neutral    0.999999
# 49  Just not good... This movie is just not good.....  neutral    0.999838
#
#     rating  text_length
# 0      6.0         3130
# 1      3.0          308
# 2      7.0          523
# 3      1.0         1160
# 4      7.0         2988
# 5      6.0          202
# 6      8.0          992
# 7      6.0         1109
# 8      1.0          475
# 9      7.0          135
# 10     1.0          226
# 11     7.0          359
# 12     1.0          447
# 13     1.0          508
# 14     7.0         2406
# 15     2.0          245
# 16     1.0          384
# 17     7.0          426
# 18     1.0          256
# 19     7.0          226
# 20     1.0          137
# 21     1.0          288
# 22     6.0          309
# 23     7.0          194
# 24     7.0          852
# 25     2.0          186
# 26    10.0          213
# 27     6.0          400
# 28     1.0          635
# 29     2.0         4072
# 30     7.0         1494
# 31     1.0          294
# 32     7.0          104
# 33     2.0           70
# 34     7.0          478
# 35     8.0          704
# 36     7.0         3652
# 37     5.0          867
# 38     1.0          694
# 39     6.0          514
# 40     1.0          147
# 41     7.0         5310
# 42     2.0          267
# 43     7.0         1404
# 44     4.0         1552
# 45     8.0          116
# 46     1.0         2306
# 47     1.0         4466
# 48     1.0          278
# 49     1.0          123

# %%
df_purge_neutral = split_by_politics(df_purge_predicted, 'neutral')
print(len(df_purge_neutral))
display(display_df_with_style(df_purge_neutral))
# Out:
# 403
# <style type="text/css">
# #T_1baab th {
#   text-align: left;
# }
# #T_1baab td {
#   text-align: left;
#   white-space: pre-wrap;
#   border: 1px solid black;
#   font-family: consolas;
# }
# </style>
# <table id="T_1baab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1baab_level0_col0" class="col_heading level0 col0" >review_title</th>
#       <th id="T_1baab_level0_col1" class="col_heading level0 col1" >document</th>
#       <th id="T_1baab_level0_col2" class="col_heading level0 col2" >politics</th>
#       <th id="T_1baab_level0_col3" class="col_heading level0 col3" >confidence</th>
#       <th id="T_1baab_level0_col4" class="col_heading level0 col4" >rating</th>
#       <th id="T_1baab_level0_col5" class="col_heading level0 col5" >text_length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1baab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1baab_row0_col0" class="data row0 col0" >Weakest of The Purge films, but it remains a flawed but fascinating franchise</td>
#       <td id="T_1baab_row0_col1" class="data row0 col1" >Weakest of The Purge films, but it remains a
# flawed but fascinating franchise This fourth
# installment in the fascinating, but flawed
# dystopian franchise, does succeed in begin
# exciting and never boring, but as with the prior
# films remains a disappointment considering the
# awesome and frightening premiss. However, in this
# film's favor, it does fill in some of the logic
# gaps of the previous films, answering some
# persistent lingering questions in this prequel of
# the first ever limited Purge on Staton Island, Are
# people really so depraved to go on killing
# rampages one day a year? How could the economy and
# crime rates improve as a result of a yearly purge?
# Who would benefit from such an event? Much is
# explained in this installment. The totalitarian
# New Founding Fathers need this first purge to be a
# success, so when the brown and poverty stricken
# residents of Staten Island don't riot and kill,
# they send in a Blackwater type of group to make
# sure there are plenty of killings in hopes of
# turning citizens against one another. When the
# leader of the Blackwater group is a dead ringer or
# Ronny Regan, it's not hard to guess where this
# film's politics lie and the filmmakers opinion of
# our current president and his divisive style of
# politics for personal enrichment (At one point,
# the heroine refers to one of her attackers as a
# "pussy-grabber," a pretty direct Trump
# reference.). As with the other films, this one
# follows a disparate group of folks trying to
# survive the 12-hour Purge, primarily an anti-purge
# activist and a community minded drug kingpin. The
# downside to this film is similar to the others, in
# that there is not a lot of character development
# and despite a strong film concept and story set-
# up, the film quickly devolves into a series of
# action set pieces. I found this to be the weakest
# of the series when it came to action and suspense,
# but it's likely the strongest when it comes to
# better fleshing out the politics and the logic
# behind the purge. I'm also disappointed that the
# series is straying pretty significantly from it's
# horror roots in the first film and is more and
# more becoming an urban action film series. The
# first two films did an excellent job of conveying
# the frightening anarchy of the purge (the first
# film was a straight-up horror home invasion
# story), but subsequent films has felt more action
# oriented. I much preferred the uncompromising
# horror of the first films, which seemed to delve
# more into the darkness of human nature, even if
# the logic of the purge was less intelligible.
# Series creator James DeMonaco is only the writer
# this time and leaves the directing duties to
# Gerard McMurray, who does a serviceable job, but
# this film felt less apocalyptic and less surreal
# than the prior films, somewhat to it's detriment.
# After having watched this film and having started
# watching the 10 episode TV event, I think The
# Purge series needs to either become more political
# (which this film did more so) or more focused on
# simply presenting interesting scenarios and chaos
# (which the TV show is doing more of), but I keep
# feeling like there's not enough of either in any
# of these films.</td>
#       <td id="T_1baab_row0_col2" class="data row0 col2" >neutral</td>
#       <td id="T_1baab_row0_col3" class="data row0 col3" >0.997921</td>
#       <td id="T_1baab_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_1baab_row0_col5" class="data row0 col5" >3130</td>
#     </tr>
#     <tr>
#       <th id="T_1baab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1baab_row1_col0" class="data row1 col0" >Worst Purge movie out of all of them</td>
#       <td id="T_1baab_row1_col1" class="data row1 col1" >Worst Purge movie out of all of them The
# characters are underdeveloped and the acting is
# bad, which made me indifferent whether they
# survived or not. There is no real suspense, only
# random action scenes. Lastly, the "scientific
# layer" they tried to add, and the stereotypes, are
# just insulting to the viewer.</td>
#       <td id="T_1baab_row1_col2" class="data row1 col2" >neutral</td>
#       <td id="T_1baab_row1_col3" class="data row1 col3" >0.997580</td>
#       <td id="T_1baab_row1_col4" class="data row1 col4" >3.000000</td>
#       <td id="T_1baab_row1_col5" class="data row1 col5" >308</td>
#     </tr>
#     <tr>
#       <th id="T_1baab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1baab_row2_col0" class="data row2 col0" >Really amusing movie.</td>
#       <td id="T_1baab_row2_col1" class="data row2 col1" >Really amusing movie. I haven't seen the original
# Purge movies. And because this is a prequel, I
# just went to see it having 0 expectations. This
# movie has some GREAT actors (which make you notice
# some terrible acting from others). Still an
# amazing concept for a movie and I just really
# enjoyed it. Heard some negative sounds here and
# there. But everyone's a critic these days and that
# probably stops them from turning off your brain
# and just enjoy a movie. If you haven't seen the
# others than go see it! It's just good fun.</td>
#       <td id="T_1baab_row2_col2" class="data row2 col2" >neutral</td>
#       <td id="T_1baab_row2_col3" class="data row2 col3" >0.999466</td>
#       <td id="T_1baab_row2_col4" class="data row2 col4" >7.000000</td>
#       <td id="T_1baab_row2_col5" class="data row2 col5" >523</td>
#     </tr>
#     <tr>
#       <th id="T_1baab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1baab_row3_col0" class="data row3 col0" >Sigh...what a waste of potential</td>
#       <td id="T_1baab_row3_col1" class="data row3 col1" >Sigh...what a waste of potential It's a dreadful
# bore, with poor writing, and an incredibly forced
# depiction of the Black side of this fictional
# movement. Everything the film tries to start anew
# feels so out of place and none of it amounts to
# anything remotely interesting, while everything
# else feels like a forced tie in product to the
# other films before it, never directly addressing
# them, but largely relying on similar setups and
# situations that the other ones have already dealt
# with. The acting is incredibly over the top, the
# screenplay even more so, never knowing what it
# quite wants to be or wants to say. The direction
# is harsh, the tone and look of the film bleak, and
# it never decides on whether it wants to be a trip
# to empowerment or a social commentary, both of
# which the film pulls off poorly. The music is
# forced, the characters thin, and I can't think of
# many things positive about the film besides
# potential that the film so poorly executed. In the
# end, The First Purge is not only a pointless
# sequel, but a truly lackluster film, with no
# agenda but to accumulate some more money for this
# seemingly never ending franchise. My Rating:
# 2.5/10</td>
#       <td id="T_1baab_row3_col2" class="data row3 col2" >neutral</td>
#       <td id="T_1baab_row3_col3" class="data row3 col3" >0.999454</td>
#       <td id="T_1baab_row3_col4" class="data row3 col4" >1.000000</td>

# %%
df_purge_left = split_by_politics(df_purge_predicted, 'left')
print(len(df_purge_left))
df_purge_left.head(50)
# Out:
# 10
#                           review_title  \
# 55           It feels okay to Purge...
# 165  What is the point of "The Purge?"
# 171                 Love the PURGES...
# 188   This could have been good, but..
# 212                      Race massacre
# 287    Final Purge Movie is a must see
# 396                         Awesome!!!
# 405                      Too Slow 4 Me
# 457              Y'all are so confused
# 462          The first purge my review
#
#                                               document politics  confidence  \
# 55   It feels okay to Purge... This is unabashed an...     left    0.973997
# 165  What is the point of "The Purge?" I understand...     left    0.743089
# 171  Love the PURGES... What's with the bad reviews...     left    0.798428
# 188  This could have been good, but.. Just to start...     left    0.986952
# 212  Race massacre As a lover of the "the wrong" ki...     left    0.658128
# 287  Final Purge Movie is a must see When was this ...     left    0.714638
# 396  Awesome!!! This movie is the best purge movie ...     left    0.962322
# 405  Too Slow 4 Me This film is definitely my least...     left    0.889963
# 457  Y'all are so confused Lol I don't know what al...     left    0.885665
# 462  The first purge my review Watched the film las...     left    0.600337
#
#      rating  text_length
# 55      6.0         1135
# 165     6.0          603
# 171     8.0          324
# 188     6.0         1261
# 212     2.0          363
# 287     8.0          135
# 396    10.0          111
# 405     5.0          395
# 457     8.0          348
# 462     8.0          235

# %%
df_purge_right = split_by_politics(df_purge_predicted, 'right')
print(len(df_purge_right))
df_purge_right.head(50)
# Out:
# 58
#                                           review_title  \
# 11             Not as bad as described in the comments
# 33                                            my notes
# 36                        Back To Where It All Started
# 38                                An absolute disgrace
# 44   The First Purge: The First Purge is the worst ...
# 59              Another Purge another bloody fun night
# 60                                    Pain in the eyes
# 70                      Just a Hollywood Dumpster Fire
# 71   Creepy and thrilling but it does start slow an...
# 99                                     It's really bad
# 108                                    Ignore the hate
# 117  Here the action is better than the horror n it...
# 162  The 1* Reviews Are More Of A Problem Than The ...
# 168                         A prequel no one asked for
# 175     Prequel that's more futuristic than the others
# 179                             People are to critical
# 181                            Other movies was better
# 183  Needed some more backstory and character devel...
# 185  A few strong setpieces sprinkled throughout, b...
# 190                                   Hard to continue
# 204                 Does Marisa Tormei Need the Money?
# 205  Regular prequel , middlingly paced ,with lots ...
# 208                                 VERY disappointing
# 217                          Horrible left-wing drivel
# 227   The First Purge Makes Me Wonder About You Humans
# 232                                 100% waste of time
# 247                                 Not worth the look
# 263                 Purge the desire to see this movie
# 277                                Good Entertainment!
# 285                     The best part were the credits
# 293             I grew up with the purge franchise and
# 298         Lowest I can give is 1. Not even worth it.
# 319              Hard to believe this is a Purge movie
# 320                                 Middle of the road
# 328                                              Awful
# 333                  This was a shocking great movie !
# 334                      Didn't need to see this movie
# 338                                     Best Purge Yet
# 341                                             Wokish
# 343  Four Movies in and The Purge Still Makes No Sense
# 346                                        Seriously??
# 349                                 High Quality trash
# 367                         Far from being entertained
# 383                                        intro purge
# 387                                      Disappointing
# 388                              Attempt to make money
# 395                               could of been better
# 410                                           Relevant
# 416                                     Best Purge Yet
# 428                             Best out of the series
#
#                                               document politics  confidence  \
# 11   Not as bad as described in the comments First,...    right    0.932201
# 33   my notes Pointless. useless. dumb. terrible. s...    right    0.739665
# 36   Back To Where It All Started It was an idea th...    right    0.967761
# 38   An absolute disgrace I nearly missed half this...    right    0.654968
# 44   The First Purge: The First Purge is the worst ...    right    0.994343
# 59   Another Purge another bloody fun night The Pur...    right    0.879061
# 60   Pain in the eyes Waste of time to watch this. ...    right    0.818855
# 70   Just a Hollywood Dumpster Fire The First Purge...    right    0.667774
# 71   Creepy and thrilling but it does start slow an...    right    0.815902
# 99   It's really bad There's racial baiting and I a...    right    0.999291
# 108  Ignore the hate Too many violence? Close your ...    right    0.480218
# 117  Here the action is better than the horror n it...    right    0.595249
# 162  The 1* Reviews Are More Of A Problem Than The ...    right    0.938893
# 168  A prequel no one asked for If you thought the ...    right    0.741302
# 175  Prequel that's more futuristic than the others...    right    0.998209
# 179  People are to critical SPOILER: I liked it.Peo...    right    0.994971
# 181  Other movies was better Boriiing, i mean i jus...    right    0.999614
# 183  Needed some more backstory and character devel...    right    0.998196
# 185  A few strong setpieces sprinkled throughout, b...    right    0.939591
# 190  Hard to continue This movie was hardly ever en...    right    0.688325
# 204  Does Marisa Tormei Need the Money? Basically a...    right    0.559947
# 205  Regular prequel , middlingly paced ,with lots ...    right    0.996722
# 208  VERY disappointing Of the four released Purge ...    right    0.568629
# 217  Horrible left-wing drivel White guys bad, repu...    right    0.801598
# 227  The First Purge Makes Me Wonder About You Huma...    right    0.818731
# 232  100% waste of time Seems more like a last shot...    right    0.871980
# 247  Not worth the look The last movies were pretty...    right    0.995924
# 263  Purge the desire to see this movie Terrible fr...    right    0.592757
# 277  Good Entertainment! At first, I passed on seei...    right    0.991828
# 285  The best part were the credits The credits had...    right    0.999722
# 293  I grew up with the purge franchise and I grew ...    right    0.989129
# 298  Lowest I can give is 1. Not even worth it. Mov...    right    0.614011
# 319  Hard to believe this is a Purge movie One of t...    right    0.941477
# 320  Middle of the road Not sure I was the target a...    right    0.922676
# 328  Awful Just a really bad movie. The hero is a g...    right    0.678901
# 333  This was a shocking great movie ! THE FIRST PU...    right    0.999907
# 334  Didn't need to see this movie I didn't need to...    right    0.562123
# 338  Best Purge Yet Had a great convo over dinner w...    right    0.692577
# 341  Wokish None of the sequels have been very good...    right    0.986307
# 343  Four Movies in and The Purge Still Makes No Se...    right    0.994115
# 346  Seriously?? Easily the worst of the franchise....    right    0.964517
# 349  High Quality trash Conclusion: racist, confuse...    right    0.754538
# 367  Far from being entertained Really the worst Pu...    right    0.708664
# 383  intro purge Despite its low rating, it is the ...    right    0.901018
# 387  Disappointing Okay, I know, it's number four, ...    right    0.727379
# 388  Attempt to make money It was horrendous attemp...    right    0.587721
# 395  could of been better Had everything to make th...    right    0.858265
# 410  Relevant The First Purge has a lot of politica...    right    0.993758
# 416  Best Purge Yet Do not understand bad reviews!!...    right    0.901834
# 428  Best out of the series This one was for the H ...    right    0.998368
#
#      rating  text_length
# 11      7.0          359
# 33      2.0           70
# 36      7.0         3652
# 38      1.0          694
# 44      4.0         1552
# 59      7.0          762
# 60      1.0          249
# 70      1.0         1211
# 71      7.0         3053
# 99      1.0          187
# 108     8.0          118
# 117     8.0         1083
# 162     6.0         1075
# 168     4.0         1183
# 175     6.0          366
# 179     9.0          181
# 181     2.0          137
# 183     6.0          225
# 185     5.0         5294
# 190     4.0          853
# 204     1.0          287
# 205     5.0         6865
# 208     3.0          332
# 217     1.0          467
# 227     3.0         2042
# 232     1.0          180
# 247     1.0          337
# 263     1.0          314
# 277     8.0          246
# 285     4.0           98
# 293    10.0          129
# 298     1.0          233
# 319     1.0          155
# 320     5.0          107
# 328     2.0          566
# 333    10.0          961
# 334     4.0          307
# 338     8.0          834
# 341     3.0          278
# 343     2.0          694
# 346     1.0          320
# 349     2.0          216
# 367     2.0          106
# 383     4.0          394
# 387     4.0         4119
# 388     2.0          371
# 395     4.0          962
# 410    10.0          278
# 416    10.0          331
# 428    10.0          132
